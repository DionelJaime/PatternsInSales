# %% [markdown]
# # Setting up tools to use
#
# We need pandas to format the data.

# %%
import pandas as pd
import scipy.stats as stats

# %%
df = pd.read_csv('Sales_Data_CSV.csv')

# %%
print(df)
# Out:
#               order_id  order_date ship_date       ship_mode
# 0         AG-2011-2040    1/1/2011  6/1/2011  Standard Class  \
# 1        IN-2011-47883    1/1/2011  8/1/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  5/1/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  5/1/2011    Second Class
# 4        IN-2011-47883    1/1/2011  8/1/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  31-12-2014  4/1/2015  Standard Class
# 51286     MO-2014-2560  31-12-2014  5/1/2015  Standard Class
# 51287   MX-2014-110527  31-12-2014  2/1/2015    Second Class
# 51288   MX-2014-114783  31-12-2014  6/1/2015  Standard Class
# 51289   CA-2014-156720  31-12-2014  4/1/2015  Standard Class
#
#           customer_name      segment             state        country  market
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa  \
# ...

# %%
df.drop("customer_name",axis=1,inplace=True)
print(df)
# Out:
#               order_id  order_date ship_date       ship_mode      segment
# 0         AG-2011-2040    1/1/2011  6/1/2011  Standard Class     Consumer  \
# 1        IN-2011-47883    1/1/2011  8/1/2011  Standard Class     Consumer
# 2         HU-2011-1220    1/1/2011  5/1/2011    Second Class     Consumer
# 3      IT-2011-3647632    1/1/2011  5/1/2011    Second Class  Home Office
# 4        IN-2011-47883    1/1/2011  8/1/2011  Standard Class     Consumer
# ...                ...         ...       ...             ...          ...
# 51285   CA-2014-115427  31-12-2014  4/1/2015  Standard Class    Corporate
# 51286     MO-2014-2560  31-12-2014  5/1/2015  Standard Class     Consumer
# 51287   MX-2014-110527  31-12-2014  2/1/2015    Second Class     Consumer
# 51288   MX-2014-114783  31-12-2014  6/1/2015  Standard Class     Consumer
# 51289   CA-2014-156720  31-12-2014  4/1/2015  Standard Class     Consumer
#
#                   state        country  market   region        product_id
# ...

# %%
African_Region = df[df['region']=="Africa"].drop(["region","market"],axis=1)
print(African_Region)
# Out:
#            order_id  order_date  ship_date       ship_mode      segment
# 0      AG-2011-2040    1/1/2011   6/1/2011  Standard Class     Consumer  \
# 23     TZ-2011-7370    3/1/2011   8/1/2011  Standard Class     Consumer
# 41     SU-2011-5190    4/1/2011   8/1/2011  Standard Class     Consumer
# 42     SU-2011-5190    4/1/2011   8/1/2011  Standard Class     Consumer
# 55     AO-2011-4910    6/1/2011  11/1/2011  Standard Class    Corporate
# ...             ...         ...        ...             ...          ...
# 51252  OD-2014-9490  31-12-2014   5/1/2015  Standard Class    Corporate
# 51253  AO-2014-7730  31-12-2014   4/1/2015  Standard Class     Consumer
# 51262  TZ-2014-8350  31-12-2014   3/1/2015     First Class     Consumer
# 51280  TZ-2014-8220  31-12-2014   6/1/2015  Standard Class  Home Office
# 51286  MO-2014-2560  31-12-2014   5/1/2015  Standard Class     Consumer
#
#                    state      country        product_id         category
# ...

# %%
EMEA_Region = df[df['region']=="EMEA"].drop(["region","market"],axis=1)
print(EMEA_Region)
# Out:
#            order_id  order_date ship_date       ship_mode    segment
# 2      HU-2011-1220    1/1/2011  5/1/2011    Second Class   Consumer  \
# 9      IZ-2011-4680    3/1/2011  7/1/2011  Standard Class  Corporate
# 16      IR-2011-770    3/1/2011  7/1/2011  Standard Class   Consumer
# 21     IR-2011-7690    3/1/2011  8/1/2011    Second Class  Corporate
# 22      IR-2011-770    3/1/2011  7/1/2011  Standard Class   Consumer
# ...             ...         ...       ...             ...        ...
# 51249  TU-2014-5170  31-12-2014  4/1/2015    Second Class   Consumer
# 51255  RS-2014-1460  31-12-2014  2/1/2015    Second Class   Consumer
# 51258  UP-2014-3330  31-12-2014  2/1/2015     First Class  Corporate
# 51274  TU-2014-5170  31-12-2014  4/1/2015    Second Class   Consumer
# 51282  UP-2014-4410  31-12-2014  4/1/2015  Standard Class   Consumer
#
#                  state  country        product_id         category
# 2             Budapest  Hungary  OFF-TEN-10001585  Office Supplies  \
# ...
